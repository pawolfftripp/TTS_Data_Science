# %%
# 1. Accept the user's first and last name and print them in reverse order with a space between them
def reverse_name():
    """reverses user input of first and last name ex: Perry Wolff --> ffloW yrreP"""
    # asks user for first name
    first_name = input("What is your first name? ")
    # asks user for last name
    last_name = input("What is your last name? ")
    # concatenates first name and last name with a space between
    full_name = first_name + " " + last_name
    #converts full_name to a list
    name_list = list(full_name)
    # [start:stop:step] -1 (if no start and stop is defined, runs through each value in list)
    reversed_name = name_list[::-1]
    # joins values in list with no spacing and converts variable reversed_name to string 
    list_to_string = ''.join(map(str, reversed_name))

    #check that list_to_string variable is in fact (now) a string
    #print(type(list_to_string))

    # f string with variable passed into curly braces
    print(f"Your name is: {full_name}")
    print(f"Your name reversed is: {list_to_string}")

# 2. Accept an integer (n) and compute the value of n+nn+nnn 
def multiply_value():
    while True:
        try:
            n = int(input("Pick a number, please? "))   
            multiply_n = (n) + (n*n) + (n*n*n)
            print(multiply_n)
            break
            
        except ValueError:
            print("that is not a number, try again.")
            multiply_value()

# 3. Ask the user "What country are you from?" then print the following statement: "I have heard that [input] is a beautiful country!"
def ask_country():
    user_country = input("What country are you from? ")
    print(f"I have heard that {user_country} is a beautiful country!")

# 4. What is the output of x AND explain why that is the output for: 
def output_x():
    x = 36/4 * (3+2) * 4+2
    print(f"The answer to \'x = 36 / 4 * (3 + 2) * 4 + 2\' is {x}, because '36 / 4' evaluates to 9 , '(3 + 2)' evaluates to 5, and '4 + 2' is not wrapped in parenthesis. \n When simplified, the equation looks like this (9 * 5 * 4) + 2  or 180 + 2. I am assuming this is correct?")

# 5. Is a string immutable in python?
def is_immutable():
    print("Is a string immutable in python? Yes it is...")

def function_selector():
    select = input("Select a function from this list to run see what happens: <multiply_value, reverse_name, ask_country, output_x, is_immutable>")

    if select == 'multiply_value':
        multiply_value()
        user_input = input('Would you like to run another function? y/n ')
        if user_input == 'y':
            function_selector()
        else:
            print("well fine. don't select another function.")
                
    elif select == 'reverse_name':
        reverse_name()
        user_input = input('Would you like to run another function? y/n ')
        if user_input == 'y':
            function_selector()
        else:
            print("well fine. don't select another function.")    
                
    elif select == 'ask_country':
        ask_country()
        user_input = input('Would you like to run another function? y/n ')
        if user_input == 'y':
            function_selector()
        else:
            print("well fine. don't select another function.")       
     
    elif select == 'output_x':
        output_x() 
        user_input = input('Would you like to run another function? y/n ')
        if user_input == 'y':
            function_selector()
        else:
            print("well fine. don't select another function.")

    elif select == 'is_immutable':
        is_immutable()
        user_input = input('Would you like to run another function? y/n ')
        if user_input == 'y':
            function_selector()
        else:
            print("well fine. don't select another function.")
                
    else:
        print("invalid command, please try again")

function_selector()
